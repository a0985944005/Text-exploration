# %%
import requests
url ="https://tw.yahoo.com/"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html id="Stencil" lang="zh-Hant-TW" class="StencilRoot  my3columns  l-out Pos-r https fp fp-default uh-topbar-on ltr desktop Desktop bkt900">
# <head>
#
#     <title>Yahoo奇摩</title><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s.yimg.com"><link rel="preconnect" href="//s.yimg.com"><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"><link rel="preconnect" href="//csc.beap.bc.yahoo.com"><link rel="dns-prefetch" href="//geo.yahoo.com"><link rel="preconnect" href="//geo.yahoo.com"><link rel="dns-prefetch" href="//comet.yahoo.com"><link rel="preconnect" href="//comet.yahoo.com"><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"><link rel="preconnect" href="//video-api.yql.yahoo.com">    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#
#     <meta http-equiv="X-UA-Compatible" content="chrome=1">
#     <meta name="description" content="新聞、電子信箱和搜尋功能只是起點。每天發掘更多精彩內容。打造專屬自我的 Yahoo奇摩體驗。">
# ...

# %%
import requests
url="https://www.setn.com/news.aspx?newsid=225139"
r = requests.get(url)
if '寵妻狂魔'in r.text:
    print("有的")
# Out:
# 有的

# %%
import requests
url = 'https://freshman.tw/ajax/ajax_mysql.php'
from_data={
    'q': '林怡君',
    'y': '105+all',
    't': 'name',
    'init': '1'
}
request_headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
    'referer': 'https://freshman.tw/',
}
r = requests.post(url,data=from_data,headers=request_headers)
r.encoding='utf-8'
print(r.text)
print()
r_dict=r.json()
data_list=r_dict['data']
for d in data_list:
    print(d)
# Out:
# {"exam_name":"105\u7d9c\u5408\u67e5\u8a62","time":0.00464,"uac":[],"data":[{"number":"10044331","name":"\u6797\u6021\u541b","school":"\u4e2d\u570b\u91ab\u85e5\u5927\u5b78","dept":"\u91ab\u5b78\u7cfb","exam_type":"\u500b\u4eba\u7533\u8acb","extra":""},{"number":"10248321","name":"\u6797\u6021\u541b","school":"\u9022\u7532\u5927\u5b78","dept":"\u571f\u5730\u7ba1\u7406\u5b78\u7cfb","exam_type":"\u500b\u4eba\u7533\u8acb","extra":""},{"number":"10319233","name":"\u6797\u6021\u541b","school":"\u6771\u6d77\u5927\u5b78","dept":"\u9910\u65c5\u7ba1\u7406\u5b78\u7cfb","exam_type":"\u500b\u4eba\u7533\u8acb","extra":""},{"number":"10014834","name":"\u6797\u6021\u541b","school":"\u5be6\u8e10\u5927\u5b78","dept":"\u570b\u969b\u4f01\u696d\u7ba1\u7406\u5b78\u7cfb(\u9ad8\u96c4\u6821\u5340)","exam_type":"\u500b\u4eba\u7533\u8acb","extra":""},{"number":"10210504","name":"\u6797\u6021\u541b","school":"\u4e9e\u6d32\u5927\u5b78","dept":"\u807d\u529b\u66a8\u8a9e\u8a00\u6cbb\u7642\u5b78\u7cfb","exam_type":"\
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs

url='https://www.setn.com/news.aspx?newsid=225139'
request_headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36' '(KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}
r=requests.get(url,headers=request_headers)
soup=bs(r.text,'lxml')
 #兩個標籤中的空格代表著後者可為前者的子標籤或孫標籤(標籤已改)
# category=soup.select('#toptitle a')[1].text
# print(category)

#兩個標籤中的>代表後者必須為前者的子標籤(標籤已改)
# title=soup.select('giv.title>h1')[0].text
# print(title)

#擷取class='date'的標籤，不限標籤名稱(標籤已改)
# post_time=soup.select('.date')[0].text
# print(post_time)

content=soup.select('#Content1')[0].text
print(content)
# Out:
# 娛樂中心／綜合報導女星Angelababy（楊穎）和老公黃曉明結婚1年多，上月17日在香港順利產下寶貝兒子「小海綿」，而以寵妻出了名的黃曉明，對老婆Angelababy更是呵護備至，近日有網友在微博曝光黃曉明辦公室一角的照片，沒想到意外發現夫妻倆的銅像，讓網友羨慕直呼「寵妻狂魔黃教主！」▲黃曉明對Angelababy呵護備至。（圖／翻攝自微博）有網友今（15）日在微博曬出黃曉明的辦公室內部照，赫然驚見辦公室擺放著他與Angelababy緊緊相擁的銅像，該銅像是依照夫妻倆婚紗照等比例縮放製作，只見戴著王冠的Angelababy和穿著西裝的黃曉明，都顯得十分逼真。照片曝光後，網友紛紛留言「服了！真愛無敵」、「讓人羨慕的一對」，還有網友開玩笑表示「銅像有點恐怖」。▲黃曉明的辦公室擺放夫妻倆銅像。（圖／翻攝自微博）
